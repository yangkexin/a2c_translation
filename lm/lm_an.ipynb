# %%
# %run main.py --cuda
# Out:
# read file: ./data/a2c/an/all_an.txt
# read file: ./data/a2c/an/valid.txt
# read file: ./data/a2c/an/test.txt
# | epoch   1 |   200/120557 batches | lr 20.00 | ms/batch  7.15 | loss  7.64 | ppl  2074.56
# | epoch   1 |   400/120557 batches | lr 20.00 | ms/batch  6.52 | loss  6.14 | ppl   464.53
# | epoch   1 |   600/120557 batches | lr 20.00 | ms/batch  6.62 | loss  5.81 | ppl   332.45
# | epoch   1 |   800/120557 batches | lr 20.00 | ms/batch  6.55 | loss  5.55 | ppl   257.00
# | epoch   1 |  1000/120557 batches | lr 20.00 | ms/batch  6.96 | loss  5.30 | ppl   200.70
# | epoch   1 |  1200/120557 batches | lr 20.00 | ms/batch  6.95 | loss  5.21 | ppl   184.00
# | epoch   1 |  1400/120557 batches | lr 20.00 | ms/batch  6.23 | loss  5.08 | ppl   160.31
# | epoch   1 |  1600/120557 batches | lr 20.00 | ms/batch  6.81 | loss  5.16 | ppl   173.54
# | epoch   1 |  1800/120557 batches | lr 20.00 | ms/batch  6.61 | loss  5.20 | ppl   181.82
# ...

# %%
# %run main.py --cuda --emsize 512 --save_dict 'dict.an.pkl'\
             --nhid 512 --nlayers 2\
             --lr 20 --lr_decay_rate 0.9 --clip 0.5 \
             --epochs 200 --batch_size 128 \
             --bptt 40 --dropout 0.2 \
             --tied --log-interval 2000 \
             --save "a2c_an_new.pt"
# Out:
# read file: ./data/a2c/an/an_lm_train.txt
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /home/workspace/dual_learning/lm/main.py in <module>()
#      62 ###############################################################################
#      63
# ---> 64 corpus = data.Corpus(args.data,args.save_dict)
#      65
#      66 # Starting from sequential data, batchify arranges the dataset into columns.
#
# /home/workspace/dual_learning/lm/data.py in __init__(self, path, dictsavepath)
#      31     def __init__(self, path, dictsavepath):
#      32         self.dictionary = Dictionary()
# ---> 33         self.train = self.tokenize(os.path.join(path, 'an_lm_train.txt'))
#      34         self.valid = self.tokenize(os.path.join(path, 'an_lm_valid.txt'))
#      35         self.test = self.tokenize(os.path.join(path, 'an_lm_test.txt'))
#
# ...

# %% [markdown]
# ## with attention

# %%
python3 main.py --cuda --emsize 200 --save_dict 'dict.an.pkl'\
             --nhid 200 --nlayers 2\
             --lr 20 --lr_decay_rate 0.9 --clip 0.5 \
             --epochs 200 --batch_size 128 \
             --bptt 40 --dropout 0.2 \
             --log-interval 2000 \
             --save "a2c_an_attention.pt"
# Out:
# read file: ./data/a2c/an/an_lm_train.txt
# read file: ./data/a2c/an/an_lm_valid.txt
# read file: ./data/a2c/an/an_lm_test.txt
